# %% [markdown]
# # Load Dependencis

# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio

# %% [markdown]
# # 2. Build Data Loading Function

# %% [markdown]
# ## 2.1 Define Paths To Files ##

# %%
CAPUCHIN_FILE = os.path.join('data', '/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Parsed_Capuchinbird_Clips','XC114131-0.wav')
NOT_CAPUCHIN_FILE = os.path.join('data', '/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Parsed_Not_Capuchinbird_Clips', 'afternoon-birds-song-in-forest-0.wav')

# %% [markdown]
# ## 2.1 Build Dataloading Function ##

# %%
def load_wav_16k_mono(filename):
    # Load encoded wav file
    file_contents = tf.io.read_file(filename)
    # Decode wav (tensors by channels) 
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    # Removes trailing axis
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    # Goes from 44100Hz to 16000hz - amplitude of the audio signal
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %% [markdown]
# ## 2.2 Plot Wave ##

# %%
wave = load_wav_16k_mono(CAPUCHIN_FILE)
nwave = load_wav_16k_mono(NOT_CAPUCHIN_FILE)

# %%
plt.plot(wave)
plt.plot(nwave)
plt.show()

# %% [markdown]
# # Create Tensorflow Dataset

# %% [markdown]
# ## 3.1 Define paths to positive and negative data

# %%
POS = os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Parsed_Capuchinbird_Clips')
NEG = os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Parsed_Not_Capuchinbird_Clips')

# %%
import os

pos_files = os.listdir(POS)
neg_files = os.listdir(NEG)

print("Positive files:", pos_files)
print("Negative files:", neg_files)
# Out:
# Positive files: ['XC27882-2.wav', 'XC227469-2.wav', 'XC456236-3.wav', 'XC227471-6.wav', 'XC227468-3.wav', 'XC513083-1.wav', 'XC216012-12.wav', 'XC9892-0.wav', 'XC27882-0.wav', 'XC227469-3.wav', 'XC433953-10.wav', 'XC79965-10.wav', 'XC526106-4.wav', 'XC46241-4.wav', 'XC600460-0.wav', 'XC201990-4.wav', 'XC388470-5.wav', 'XC114132-4.wav', 'XC227471-3.wav', 'XC9221-0.wav', 'XC433953-8.wav', 'XC46241-1.wav', 'XC178168-4.wav', 'XC216012-19.wav', 'XC395129-4.wav', 'XC227468-2.wav', 'XC46241-2.wav', 'XC216012-3.wav', 'XC216010-7.wav', 'XC216012-8.wav', 'XC65196-2.wav', 'XC3776-4.wav', 'XC3776-2.wav', 'XC526106-0.wav', 'XC456236-0.wav', 'XC3776-3.wav', 'XC114132-5.wav', 'XC27882-5.wav', 'XC178168-2.wav', 'XC79965-2.wav', 'XC307385-0.wav', 'XC600460-1.wav', 'XC9221-1.wav', 'XC433953-9.wav', 'XC16804-0.wav', 'XC178167-1.wav', 'XC388470-6.wav', 'XC456236-1.wav', 'XC22397-1.wav', 'XC216012-0.wav', 'XC216010-1.wav', 'XC227468-5.wav', 'XC216012-4.wav', 'XC433953-2.wav', 'XC16804-1.wav', 'XC114131-3.wav', 'XC65196-4.wav', 'XC46241-3.wav', 'XC495697-1.wav', 'XC216010-5.wav', 'XC216010-0.wav', 'XC227471-5.wav', 'XC479556-0.wav', 'XC3776-1.wav', 'XC16803-2.wav', 'XC27881-1.wav', 'XC114131-1.wav', 'XC307385-2.wav', 'XC433953-6.wav', 'XC3776-6.wav', 'XC227471-2.wav', 'XC27881-2.wav', 'XC216012-7.wav', 'XC79965-7.wav', 'XC227471-4.wav', 'XC216012-14.wav', 'XC495697-0.wav', 'XC227471-7.wav', 'XC216012-18.wav', 'XC22397-0.wav', 'XC227469-4.wav', 'XC27881-3.wav', 'XC178167-2.wav', 'XC201990-
-43.wav', 'sparrow-sound-effect-13.wav', 'cricket-sounds-for-sleep-7.wav', 'cricket-sounds-for-sleep-2.wav', 'birds-singing-in-forest-sounds-50.wav', 'sparrow-sound-effect-14.wav', 'sparrow-sound-effect-28.wav', 'sparrow-sound-effect-44.wav', 'sparrow-sound-effect-45.wav', 'birds-singing-in-forest-sounds-47.wav', 'flock-of-pigeons-cooing-sound-effect-1.wav', 'night-insect-sounds-44.wav', 'birds-singing-in-forest-sounds-41.wav', 'crickets-sound-effect-4.wav', 'rain-thunder-and-crickets-sound-effect-0.wav', 'birds-singing-in-forest-sounds-40.wav', 'sparrow-sound-effect-35.wav', 'dove-bird-sounds-1.wav', 'crickets-chirping-crickets-sound-6.wav', 'rain-thunder-and-crickets-sound-effect-40.wav', 'birds-singing-in-forest-sounds-25.wav', 'rain-thunder-and-crickets-sound-effect-37.wav', 'cricket-sounds-for-sleep-52.wav', 'screech-owl-sounds-at-night-7.wav', 'rain-thunder-and-crickets-sound-effect-47.wav', 'night-insect-sounds-8.wav', 'crow-cawing-sound-effect-1.wav', 'cricket-sounds-for-sleep-36.wav', 'cricket-sounds-for-sleep-58.wav', 'night-insect-sounds-13.wav', 'bobwhite-quail-sound-16.wav', 'rain-thunder-and-crickets-sound-effect-14.wav', 'bobwhite-quail-sound-19.wav', 'crickets-sound-effect-20.wav', 'crow-cawing-sound-effect-13.wav', 'screech-owl-sounds-at-night-1.wav', 'killdeer-sound-3.wav', 'rain-thunder-and-crickets-sound-effect-6.wav',  ...

# %% [markdown]
# ## 3.2 Create Tensorflow Datasets

# %%
pos = tf.data.Dataset.list_files(POS + '/*-*.wav')
neg = tf.data.Dataset.list_files(NEG + '/*-*.wav')

# %% [markdown]
# ## 3.2 Add labels and combine positive and negative samples

# %%
positives = tf.data.Dataset.zip((pos, tf.data.Dataset.from_tensor_slices(tf.ones(len(pos)))))
negatives = tf.data.Dataset.zip((neg, tf.data.Dataset.from_tensor_slices(tf.zeros(len(neg)))))

# %%
data = positives.concatenate(negatives)

# %% [markdown]
# # 4. Determine Average Length of a capucin call

# %% [markdown]
# ## 4.1 calculate wave cycle length

# %%
lengths = []
for file in os.listdir(os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Parsed_Not_Capuchinbird_Clips')):
    file_path = os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Parsed_Not_Capuchinbird_Clips', file)
#     print("Current file path:", file_path)
    tensor_wave = load_wav_16k_mono(file_path)
    lengths.append(len(tensor_wave))

# %% [markdown]
# ## 4.2 calculate mean, min  and max

# %%
tf.math.reduce_mean(lengths)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=49297>

# %%
tf.math.reduce_min(lengths)
tf.math.reduce_max(lengths)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=63087>

# %% [markdown]
# # Build Preprocessing Function

# %% [markdown]
# ## 5.1 Build Preprocessing Function

# %%
def preprocess(file_path, label): 
    wav = load_wav_16k_mono(file_path)
    wav = wav[:48000]
    zero_padding = tf.zeros([48000] - tf.shape(wav), dtype=tf.float32)
    wav = tf.concat([zero_padding, wav],0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram, label

# %% [markdown]
# ## 5.2 Test out the function and viz spectrogram

# %%
filepath, label = positives.shuffle(buffer_size=10000).as_numpy_iterator().next()

# %%
spectrogram, label = preprocess(filepath, label)

# %%
plt.figure(figsize=(30,20))
plt.imshow(tf.transpose(spectrogram)[0])
plt.show()

# %% [markdown]
# # Creating Training and Testing Partisions

# %% [markdown]
# ## 6.1 create a tensorflow data pipeline

# %%
data = data.map(preprocess)
data = data.cache()
data = data.shuffle(buffer_size = 10000)
data = data.batch(16)
data = data.prefetch(8)

# %% [markdown]
# ## 6.2 Split into Training and Testing Partitions ##

# %%
train = data.take(36)
test = data.skip(36).take(15)

# %% [markdown]
# ## 6.3 Test One Batch

# %%
samples, labels = train.as_numpy_iterator().next()

# %%
samples.shape
# Out:
# (16, 1491, 257, 1)

# %% [markdown]
# # Build Deep Learning Model

# %% [markdown]
# ## 7.1 Load Tensorflow Dependencies

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten, Dropout,BatchNormalization

# %% [markdown]
# ## 7.2 Build Sequential Model, Compile and View Summary

# %%
model = Sequential()
model.add(Conv2D(16,(3,3),activation='relu', input_shape=(1491,257,1)))
model.add(Conv2D(16,(3,3),activation='relu'))
model.add(Flatten())
# model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
model.compile('Adam', loss='BinaryCrossentropy', metrics=[tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 1489, 255, 16)     160
#
#  conv2d_1 (Conv2D)           (None, 1487, 253, 16)     2320
#
#  flatten (Flatten)           (None, 6019376)           0
#
#  dense (Dense)               (None, 1)                 6019377
#
# =================================================================
# Total params: 6021857 (22.97 MB)
# Trainable params: 6021857 (22.97 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Fit Model, View Loss and KPl Plots

# %%
history = model.fit(train, epochs=15, validation_data=test)
# Out:
# Epoch 1/15
# 36/36 [==============================] - 85s 2s/step - loss: 0.8076 - recall: 0.8874 - precision: 0.8535 - val_loss: 0.2051 - val_recall: 0.9375 - val_precision: 0.9677
# Epoch 2/15
# 36/36 [==============================] - 84s 2s/step - loss: 0.1170 - recall: 0.9484 - precision: 0.9671 - val_loss: 0.0227 - val_recall: 0.9808 - val_precision: 0.9808
# Epoch 3/15
# 36/36 [==============================] - 86s 2s/step - loss: 0.0246 - recall: 0.9748 - precision: 0.9873 - val_loss: 0.0074 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 4/15
# 36/36 [==============================] - 92s 3s/step - loss: 0.0084 - recall: 0.9932 - precision: 1.0000 - val_loss: 0.0058 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 5/15
# 36/36 [==============================] - 92s 3s/step - loss: 0.1043 - recall: 0.9477 - precision: 0.9797 - val_loss: 0.0124 - val_recall: 0.9825 - val_precision: 0.9825
# Epoch 6/15
# 36/36 [==============================] - 89s 2s/step - loss: 0.0816 - recall: 0.9936 - precision: 0.9936 - val_loss: 0.0025 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 7/15
# 36/36 [==============================] - 86s 2s/step - loss: 0.0017 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0322 - val_recall: 1.0000 - val_precision: 0.9851
# Epoch 8/15
# 36/36 [==============================] - 84s 2s/step - loss: 0.0031 - recall: 1.0000 - precision: 1.0000 - val_loss: 8.9426e-04 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 9/15
# 36/36 [==============================] - 84s 2s/step - loss: 0.0362 - recall: 0.9820 - precision: 0.9880 - val_loss: 0.0062 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 10/15
# 36/36 [==============================] - 86s 2s/step - loss: 0.0033 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0034 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 11/15
# 36/36 [==============================] - 86s 2s/step - loss: 0.0025 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0012 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 12/15
# 36/36 [==============================] - 84s 2s/step - loss: 0.0011 - recall: 1.0000 - precision: 1.0000 - val_loss: 0.0011 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 13/15
# 36/36 [==============================] - 86s 2s/step - loss: 6.9208e-04 - recall: 1.0000 - precision: 1.0000 - val_loss: 5.4610e-04 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 14/15
# 36/36 [==============================] - 84s 2s/step - loss: 6.4356e-04 - recall: 1.0000 - precision: 1.0000 - val_loss: 6.7053e-04 - val_recall: 1.0000 - val_precision: 1.0000
# Epoch 15/15
# 36/36 [==============================] - 84s 2s/step - loss: 7.0404e-04 - recall: 1.0000 - precision: 1.0000 - val_loss: 6.3294e-04 - val_recall: 1.0000 - val_precision: 1.0000

# %%
model.evaluate(test)
# Out:
# 15/15 [==============================] - 8s 510ms/step - loss: 9.3233e-05 - recall: 1.0000 - precision: 1.0000
# [9.323313133791089e-05, 1.0, 1.0]

# %%
model.save('model.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
plt.title('Loss')
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'b')
plt.show()

# %% [markdown]
# # Make Prediction on single clip

# %% [markdown]
# ## 8.1 get one batch and make prediction

# %%
xtest,ytest = test.as_numpy_iterator().next()

# %%
yhat = model.predict(xtest)
# Out:
# 1/1 [==============================] - 1s 594ms/step

# %% [markdown]
# ## Convert Logits to classes

# %%
yhat = [1 if prediction > 0.5 else 0 for prediction in yhat]

# %% [markdown]
# # Build Forest Parsing Function

# %% [markdown]
# ## 9.1 load up mp3s

# %%
def load_mp3_16k_mono(filename):
    """ Load an MP3 file, convert it to a float tensor, and resample to 16 kHz single-channel audio. """
    res = tfio.audio.AudioIOTensor(filename)
    
    # Convert to tensor and combine channels
    tensor = res.to_tensor()
    tensor = tf.math.reduce_sum(tensor, axis=1) / 2
    
    # Extract sample rate and cast
    sample_rate = res.rate
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    
    # Resample to 16 KHz
    wav = tfio.audio.resample(tensor, rate_in=sample_rate, rate_out=16000)
    
    return wav

# %%
mp3 = os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Forest Recordings','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Forest Recordings/recording_00.mp3')

# %%
wav = load_mp3_16k_mono(mp3)

# %%
audio_slice = tf.keras.utils.timeseries_dataset_from_array(wav, wav, sequence_length=48000, sequence_stride=48000, batch_size=1)

# %%
sample, index = audio_slice.as_numpy_iterator().next()

# %% [markdown]
# ## 9.2 Build Function to convert clips into windowed spectrogram

# %%
def preprocess_mp3(sample, index):
    sample = sample[0]
    zero_padding = tf.zeros([48000] - tf.shape(sample), dtype=tf.float32)
    wav = tf.concat([zero_padding, sample],0)
    spectrogram = tf.signal.stft(wav, frame_length=320, frame_step=32)
    spectrogram = tf.abs(spectrogram)
    spectrogram = tf.expand_dims(spectrogram, axis=2)
    return spectrogram

# %% [markdown]
# # 9.3 convert longer clips into windows and make predictions

# %%
audio_slice = tf.keras.utils.timeseries_dataset_from_array(wav, wav, sequence_length=16000, sequence_stride=16000, batch_size=1)
audio_slice = audio_slice.map(preprocess_mp3)
audio_slice = audio_slice.batch(64)

# %%
yhat = model.predict(audio_slice)
yhat  = [ 1 if prediction > 0.5 else 0 for prediction in yhat]
# Out:
# 3/3 [==============================] - 7s 2s/step

# %% [markdown]
# ## 9.4 Group Consenutive Detectons

# %%
from itertools import groupby
yhat = [ key for key, group in groupby(yhat)]
calls = tf.math.reduce_sum(yhat).numpy()

# %%
calls
# Out:
# 5

# %% [markdown]
# # 10 Make Prediction

# %% [markdown]
# ## 10.1 Loop over all recordings and make prediction

# %%
results = {}
for file in os.listdir(os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Forest Recordings')):
    FILEPATH = os.path.join('data','/kaggle/input/z-by-hp-unlocked-challenge-3-signal-processing/Forest Recordings',file)
    
    wav = load_mp3_16k_mono(FILEPATH)
    audio_slices = tf.keras.utils.timeseries_dataset_from_array(wav, wav, sequence_length=48000, sequence_stride=48000, batch_size=1)
    audio_slices = audio_slices.map(preprocess_mp3)
    audio_slices = audio_slices.batch(64)
    yhat = model.predict(audio_slices)
    results[file] = yhat
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# ## Convert predictions into classes

# %%
class_preds = {}
for file, logits in results.items():
    class_preds[file] = [1 if prediction > 0.99 else 0 for prediction in logits]
# class_preds

# %% [markdown]
# ## 10.3 Group Consective Detections

# %%
postprocessd = {}
for file, scores in class_preds.items():
    postprocessd[file] = tf.math.reduce_sum([key for key, group in groupby(scores)]).numpy()
postprocessd
# Out:
# {'recording_76.mp3': 0,
#  'recording_62.mp3': 0,
#  'recording_48.mp3': 4,
#  'recording_44.mp3': 1,
#  'recording_45.mp3': 3,
#  'recording_06.mp3': 5,
#  'recording_43.mp3': 5,
#  'recording_68.mp3': 1,
#  'recording_95.mp3': 5,
#  'recording_17.mp3': 3,
#  'recording_65.mp3': 4,
#  'recording_74.mp3': 0,
#  'recording_10.mp3': 5,
#  'recording_49.mp3': 0,
#  'recording_15.mp3': 2,
#  'recording_37.mp3': 3,
#  'recording_64.mp3': 3,
#  'recording_39.mp3': 2,
#  'recording_04.mp3': 4,
#  'recording_28.mp3': 4,
#  'recording_05.mp3': 0,
#  'recording_80.mp3': 1,
#  'recording_57.mp3': 4,
#  'recording_12.mp3': 0,
#  'recording_59.mp3': 4,
#  'recording_67.mp3': 0,
#  'recording_09.mp3': 0,
#  'recording_79.mp3': 0,
#  'recording_14.mp3': 0,
#  'recording_63.mp3': 3,
#  'recording_86.mp3': 5,
#  'recording_47.mp3': 5,
#  'recording_03.mp3': 0,
#  'recording_33.mp3': 0,
#  'recording_08.mp3': 21,
#  'recording_51.mp3': 3,
#  'recording_35.mp3': 0,
#  'recording_81.mp3': 3,
#  'recording_30.mp3': 3,
#  'recording_88.mp3': 0,
#  'recording_75.mp3': 1,
#  'recording_46.mp3': 4,
#  'recording_19.mp3': 1,
#  'recording_90.mp3': 0,
#  'recording_69.mp3': 1,
#  'recording_40.mp3': 1,
#  'recording_58.mp3': 0,
#  'recording_31.mp3': 1,
#  'recording_73.mp3': 0,
#  'recording_85.mp3': 0,
#  'recording_29.mp3': 0,
#  'recording_02.mp3': 0,
#  'recording_66.mp3': 0,
#  'recording_23.mp3': 6,
#  'recording_22.mp3': 2,
#  'recording_27.mp3': 0,
#  'recording_25.mp3': 3,
#  'recording_32.mp3': 2,
#  'recording_84.mp3': 3,
#  'recording_61.mp3': 3,
#  'recording_87.mp3': 20,
#  'recording_53.mp3': 0,
#  'recording_96.mp3': 1,
#  'recording_16.mp3': 6,
#  'recording_26.mp3': 2,
#  'recording_11.mp3': 4,
#  'recording_54.mp3': 2,
#  'recording_91.mp3': 0,
#  'recording_13.mp3': 0,
#  'recording_92.mp3': 1,
#  'recording_94.mp3': 3,
#  'recording_60.mp3': 5,
#  'recording_55.mp3': 0,
#  'recording_36.mp3': 0,
#  'recording_56.mp3': 5,
#  'recording_93.mp3': 5,
#  'recording_72.mp3': 4,
#  'recording_70.mp3': 2,
#  'recording_38.mp3': 1,
#  'recording_18.mp3': 2,
#  'recording_98.mp3': 21,
#  'recording_21.mp3': 1,
#  'recording_83.mp3': 0,
#  'recording_89.mp3': 3,
#  'recording_01.mp3': 0,
#  'recording_78.mp3': 3,
#  'recording_41.mp3': 0,
#  'recording_52.mp3': 0,
#  'recording_77.mp3': 3,
#  'recording_42.mp3': 0,
#  'recording_20.mp3': 0,
#  'recording_82.mp3': 0,
#  'recording_07.mp3': 2,
#  'recording_24.mp3': 0,
#  'recording_99.mp3': 5,
#  'recording_97.mp3': 4,
#  'recording_50.mp3': 0,
#  'recording_71.mp3': 6,
#  'recording_34.mp3': 4,
#  'recording_00.mp3': 5}

# %% [markdown]
# # 11 Export Results

# %%
import csv
with open('results.csv','w', newline='') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(['recoding', 'capuchin_calls'])
    for key, value in postprocessd.items():
        writer.writerow([key, value])
